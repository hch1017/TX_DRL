# %%
from time import sleep
import pyautogui
from PIL import ImageGrab, Image
import pyscreeze
import cv2
#from ppg_train_faster_multi import main
from ppo_train_faster_multi import main
import time
import os
from shutil import copyfile

# %%
model_train_path = 'F:/TX_Distribution/multi_train_data/'

# %%
while(True):
    if len(os.listdir(model_train_path))!=0:
        data_path = [model_train_path + i for i in os.listdir(model_train_path)]
        main(data_path)
    else:
        time.sleep(10)
# Out:
# red reward: -0.6067798287808971
# blue reward: 0.6235890943699084
# red reward: 0.43396788766838235
# blue reward: -0.9007879825382616
# red reward: 0.31030953825311514
# blue reward: -1.0147257635733442
# red reward: 0.6814407333911586
# blue reward: 0.16261811852646688
# red reward: -0.5905085162967619
# blue reward: 0.6801396892196823
# red reward: 0.6505026563381913
# blue reward: 0.209156803206496
# red reward: 0.7204043120683113
# blue reward: 0.24072608271609136
# red reward: 0.6449569922715513
# blue reward: -0.012045939440728706
# red reward: 0.6997082915693691
# blue reward: 0.7907797816628603
# red reward: 0.7083551951214426
# blue reward: 0.49734210349836
# red reward: 0.6223003573259733
# blue reward: 0.7446944648691121
# red reward: 0.6410437766630702
# blue reward: -1.0669319943748337
# red reward: -0.3484015032390602
# blue reward: 0.6615778958688926
# red reward: 0.6410437766630702
# blue reward: -1.0669319943748337
# red reward: -0.34875444531753513
# ...
